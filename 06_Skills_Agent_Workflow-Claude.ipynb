# %% [markdown]
# # 챕터 6: Skills로 에이전트 워크플로우 자동화 만들기
#
# ## 6-1. 에이전트 워크플로우 개요
#
# 에이전트 워크플로우는 자율적으로 의사결정하고 작업을 수행하는 시스템이다.
#
# **에이전트의 특징:**
# - 목표 지향적: 최종 목표를 달성하기 위해 행동한다
# - 자율적: 스스로 다음 단계를 결정한다
# - 반응적: 환경과 상황 변화에 대응한다
# - 학습 가능: 과거 경험을 활용한다
#
# **워크플로우 패턴:**
# 1. ReAct (Reasoning + Acting): 추론하고 행동하기
# 2. Plan-Execute: 계획 수립 후 실행
# 3. Reflection: 결과를 평가하고 개선
# 4. Multi-Agent: 여러 에이전트의 협업

# %%
# 필요한 라이브러리 설치
# %pip install anthropic python-dotenv pyyaml -q

# %%
from dotenv import load_dotenv
import os

load_dotenv()
MODEL = "claude-sonnet-4-5"

# %%
import anthropic
import os
from pathlib import Path
import yaml
import json
from typing import Dict, List, Optional, Callable, Any, Union, Tuple
from dataclasses import dataclass, field
from enum import Enum
import time
from datetime import datetime
import re

# Anthropic 클라이언트 초기화
client = anthropic.Anthropic()

print("환경 설정 완료")
# Out:
# 환경 설정 완료

# %% [markdown]
# ## 6-2. 에이전트 상태 관리
#
# 에이전트의 상태와 기억을 관리하는 시스템을 구현한다.

# %%
class AgentState(Enum):
    """에이전트의 현재 상태"""
    IDLE = "idle"  # 대기
    PLANNING = "planning"  # 계획 수립
    EXECUTING = "executing"  # 실행 중
    REFLECTING = "reflecting"  # 반성 중
    COMPLETED = "completed"  # 완료
    FAILED = "failed"  # 실패

@dataclass
class AgentMemory:
    """
    에이전트의 기억과 경험을 저장한다
    """
    goal: str  # 목표
    observations: List[str] = field(default_factory=list)  # 관찰 내용
    thoughts: List[str] = field(default_factory=list)  # 생각
    actions: List[Dict] = field(default_factory=list)  # 수행한 행동
    results: List[str] = field(default_factory=list)  # 행동 결과
    learnings: List[str] = field(default_factory=list)  # 학습한 내용
    
    def add_observation(self, observation: str) -> None:
        """관찰 내용을 추가한다"""
        self.observations.append(observation)
    
    def add_thought(self, thought: str) -> None:
        """생각을 추가한다"""
        self.thoughts.append(thought)
    
    def add_action(self, action_name: str, action_input: Dict) -> None:
        """행동을 기록한다"""
        self.actions.append({
            'name': action_name,
            'input': action_input,
            'timestamp': datetime.now().isoformat()
        })
    
    def add_result(self, result: str) -> None:
        """행동 결과를 추가한다"""
        self.results.append(result)
    
    def add_learning(self, learning: str) -> None:
        """학습 내용을 추가한다"""
        self.learnings.append(learning)
    
    def get_context(self) -> str:
        """
        현재까지의 컨텍스트를 문자열로 반환한다
        
        Returns:
            컨텍스트 문자열
        """
        context = f"목표: {self.goal}\n\n"
        
        if self.observations:
            context += "관찰:\n"
            for i, obs in enumerate(self.observations[-5:], 1):  # 최근 5개만
                context += f"{i}. {obs}\n"
            context += "\n"
        
        if self.thoughts:
            context += "생각:\n"
            for i, thought in enumerate(self.thoughts[-3:], 1):  # 최근 3개만
                context += f"{i}. {thought}\n"
            context += "\n"
        
        if self.actions:
            context += "수행한 행동:\n"
            for i, action in enumerate(self.actions[-3:], 1):  # 최근 3개만
                context += f"{i}. {action['name']}\n"
            context += "\n"
        
        return context

print("에이전트 상태 관리 클래스 정의 완료")
# Out:
# 에이전트 상태 관리 클래스 정의 완료

# %% [markdown]
# ## 6-3. ReAct 에이전트 구현
#
# 추론(Reasoning)과 행동(Acting)을 반복하는 ReAct 패턴을 구현한다.

# %%
class ReActAgent:
    """
    ReAct (Reasoning + Acting) 패턴을 구현한 에이전트
    """
    
    def __init__(self, api_key: Optional[str] = None):
        """
        ReAct 에이전트를 초기화한다
        
        Args:
            api_key: Anthropic API 키
        """
        self.client = anthropic.Anthropic()
        self.skills: Dict[str, Dict] = {}  # 사용 가능한 Skills (도구)
        self.state = AgentState.IDLE
        self.memory: Optional[AgentMemory] = None
        self.max_iterations = 10  # 최대 반복 횟수
    
    def load_skill(self, skill_path: str) -> None:
        """
        Skill을 로드하여 에이전트의 도구로 등록한다
        
        Args:
            skill_path: Skill 파일 경로
        """
        with open(skill_path, 'r', encoding='utf-8') as f:
            skill_data = yaml.safe_load(f)
        
        skill_name = skill_data['name']
        self.skills[skill_name] = skill_data
        print(f"도구 등록: {skill_name}")
    
    def think(self, memory: AgentMemory) -> Tuple[str, str, Dict]:
        """
        현재 상황을 분석하고 다음 행동을 결정한다
        
        Args:
            memory: 에이전트 메모리
            
        Returns:
            (생각, 행동 이름, 행동 입력) 튜플
        """
        # 사용 가능한 도구 목록
        tools_description = "\n".join([
            f"- {name}: {skill['description']}"
            for name, skill in self.skills.items()
        ])
        
        # ReAct 프롬프트
        prompt = f"""{memory.get_context()}

사용 가능한 도구:
{tools_description}

다음 형식으로 응답해줘:

생각: [현재 상황 분석과 다음 행동에 대한 추론]
행동: [사용할 도구 이름]
입력: [도구에 전달할 입력 내용]

목표를 달성했다면:
생각: [목표 달성 이유]
행동: FINISH
입력: [최종 답변]
"""
        
        response = self.client.messages.create(
            model=MODEL,
            max_tokens=1000,
            temperature=0.7,
            messages=[
                {
                    "role": "user",
                    "content": prompt
                }
            ]
        )
        
        response_text = response.content[0].text
        
        # 응답 파싱
        thought_match = re.search(r'생각:\s*(.+?)(?=\n행동:|$)', response_text, re.DOTALL)
        action_match = re.search(r'행동:\s*(.+?)(?=\n입력:|$)', response_text)
        input_match = re.search(r'입력:\s*(.+?)(?=\n|$)', response_text, re.DOTALL)
        
        thought = thought_match.group(1).strip() if thought_match else "생각 파싱 실패"
        action = action_match.group(1).strip() if action_match else "FINISH"
        action_input = input_match.group(1).strip() if input_match else ""
        
        return thought, action, {'content': action_input}
    
    def act(self, action_name: str, action_input: Dict) -> str:
        """
        행동을 수행한다
        
        Args:
            action_name: 수행할 행동 (Skill) 이름
            action_input: 행동 입력
            
        Returns:
            행동 결과
        """
        if action_name not in self.skills:
            return f"오류: '{action_name}' 도구를 찾을 수 없다"
        
        skill = self.skills[action_name]
        config = skill.get('config', {})
        
        response = self.client.messages.create(
            model=config.get('model', MODEL),
            max_tokens=config.get('max_tokens', 2000),
            temperature=config.get('temperature', 0.7),
            system=skill['content'],
            messages=[
                {
                    "role": "user",
                    "content": action_input['content']
                }
            ]
        )
        
        return response.content[0].text
    
    def run(self, goal: str, initial_observation: str = "") -> str:
        """
        에이전트를 실행하여 목표를 달성한다
        
        Args:
            goal: 달성할 목표
            initial_observation: 초기 관찰 내용
            
        Returns:
            최종 결과
        """
        self.memory = AgentMemory(goal=goal)
        self.state = AgentState.EXECUTING
        
        if initial_observation:
            self.memory.add_observation(initial_observation)
        
        print("\n" + "=" * 80)
        print(f"에이전트 실행 시작")
        print(f"목표: {goal}")
        print("=" * 80)
        
        for iteration in range(1, self.max_iterations + 1):
            print(f"\n[반복 {iteration}/{self.max_iterations}]")
            
            # 1. 생각하기 (Reasoning)
            thought, action, action_input = self.think(self.memory)
            self.memory.add_thought(thought)
            
            print(f"생각: {thought}")
            print(f"행동: {action}")
            
            # 2. 완료 확인
            if action == "FINISH":
                final_answer = action_input['content']
                print(f"\n최종 답변: {final_answer}")
                self.state = AgentState.COMPLETED
                return final_answer
            
            # 3. 행동하기 (Acting)
            self.memory.add_action(action, action_input)
            result = self.act(action, action_input)
            self.memory.add_result(result)
            self.memory.add_observation(f"{action} 실행 결과: {result[:200]}...")
            
            print(f"결과: {result[:200]}...")
        
        # 최대 반복 횟수 초과
        print(f"\n최대 반복 횟수({self.max_iterations})에 도달했다")
        self.state = AgentState.FAILED
        return "목표를 달성하지 못했다"

print("ReActAgent 클래스 정의 완료")
# Out:
# ReActAgent 클래스 정의 완료

# %% [markdown]
# ## 6-4. 에이전트용 Skills 생성

# %%
# skills 디렉토리 생성
skills_dir = Path("skills/agent_workflow")
skills_dir.mkdir(exist_ok=True)

# 1. 웹 검색 시뮬레이터 Skill
web_search_skill = {
    'name': 'web_search',
    'version': '1.0.0',
    'description': '인터넷에서 정보를 검색한다 (시뮬레이션)',
    'content': """# 웹 검색 도구 Skill

## 역할
사용자의 검색 쿼리에 대해 관련 정보를 제공하는 웹 검색 엔진이다.

## 검색 원칙
1. 정확성: 신뢰할 수 있는 정보를 제공한다
2. 최신성: 가능한 최신 정보를 우선한다
3. 다양성: 여러 관점의 정보를 포함한다

## 출력 형식
- 검색 결과 3-5개를 제공한다
- 각 결과는 제목, 요약, 출처를 포함한다

## 주의사항
실제 웹 검색이 아닌 시뮬레이션이므로, 일반적이고 합리적인 정보를 생성한다.

## 스타일
- 문장은 ~다 체를 사용한다
- 객관적이고 정보 전달에 초점을 맞춘다
""",
    'config': {
        'max_tokens': 1500,
        'temperature': 0.5
    }
}

# 2. 계산기 Skill
calculator_skill = {
    'name': 'calculator',
    'version': '1.0.0',
    'description': '수학 계산을 수행한다',
    'content': """# 계산기 도구 Skill

## 역할
수학적 계산과 분석을 수행하는 계산기다.

## 기능
1. 기본 사칙연산
2. 복잡한 수식 계산
3. 통계 계산
4. 단위 변환

## 출력 형식
- 계산 과정을 단계별로 보여준다
- 최종 결과를 명확히 표시한다

## 스타일
- 문장은 ~다 체를 사용한다
- 정확하고 명확한 답변을 제공한다
""",
    'config': {
        'max_tokens': 1000,
        'temperature': 0.1
    }
}

# 3. 텍스트 분석 Skill
text_analyzer_skill = {
    'name': 'text_analyzer',
    'version': '1.0.0',
    'description': '텍스트를 분석하고 인사이트를 도출한다',
    'content': """# 텍스트 분석 도구 Skill

## 역할
텍스트를 다양한 관점에서 분석하는 전문가다.

## 분석 항목
1. 감정 분석: 긍정/부정/중립
2. 주제 추출: 핵심 주제와 키워드
3. 문체 분석: 톤, 스타일, 난이도
4. 구조 분석: 논리적 구조와 흐름

## 출력 형식
- 각 분석 항목별로 결과를 제시한다
- 구체적인 예시를 포함한다

## 스타일
- 문장은 ~다 체를 사용한다
- 분석적이고 객관적인 언어를 사용한다
""",
    'config': {
        'max_tokens': 2000,
        'temperature': 0.4
    }
}

# 4. 코드 생성 Skill
code_generator_skill = {
    'name': 'code_generator',
    'version': '1.0.0',
    'description': '프로그래밍 코드를 생성한다',
    'content': """# 코드 생성 도구 Skill

## 역할
요구사항에 맞는 프로그래밍 코드를 생성하는 전문가다.

## 코드 생성 원칙
1. 가독성: 이해하기 쉬운 코드를 작성한다
2. 효율성: 최적화된 알고리즘을 사용한다
3. 안정성: 에러 처리를 포함한다
4. 주석: 복잡한 로직에는 설명을 추가한다

## 지원 언어
Python, JavaScript, Java, C++, Go 등

## 출력 형식
- 완전히 동작하는 코드를 제공한다
- 사용 방법과 예제를 포함한다

## 스타일
- 문장은 ~다 체를 사용한다
- 기술적으로 정확한 설명을 제공한다
""",
    'config': {
        'max_tokens': 3000,
        'temperature': 0.6
    }
}

# Skills 저장
agent_skills = [
    web_search_skill,
    calculator_skill,
    text_analyzer_skill,
    code_generator_skill
]

for skill in agent_skills:
    skill_path = skills_dir / f"{skill['name']}.yaml"
    with open(skill_path, 'w', encoding='utf-8') as f:
        yaml.dump(skill, f, allow_unicode=True, default_flow_style=False)
    print(f"Skill 저장: {skill_path}")
# Out:
# Skill 저장: skills/agent_workflow/web_search.yaml
# Skill 저장: skills/agent_workflow/calculator.yaml
# Skill 저장: skills/agent_workflow/text_analyzer.yaml
# Skill 저장: skills/agent_workflow/code_generator.yaml

# %% [markdown]
# ## 6-5. 예제 1: 리서치 에이전트
#
# 주제를 조사하고 분석하는 자율 에이전트다.

# %%
# ReAct 에이전트 생성
research_agent = ReActAgent()

# 도구 로드
research_agent.load_skill('skills/agent_workflow/web_search.yaml')
research_agent.load_skill('skills//agent_workflow/text_analyzer.yaml')
research_agent.load_skill('skills//agent_workflow/calculator.yaml')

print("\n리서치 에이전트 준비 완료")
# Out:
# 도구 등록: web_search
# 도구 등록: text_analyzer
# 도구 등록: calculator
#
# 리서치 에이전트 준비 완료

# %%
# 에이전트 실행
goal = """
'인공지능 시장 규모'에 대해 조사하고, 
다음 정보를 포함한 종합 보고서를 작성해줘:
1. 현재 시장 규모
2. 성장 추세
3. 주요 플레이어
4. 향후 전망
"""

result = research_agent.run(
    goal=goal,
    initial_observation="인공지능 시장에 대한 정보가 필요하다"
)

print("\n" + "=" * 80)
print("최종 결과")
print("=" * 80)
print(result)
# Out:
# ================================================================================
# 에이전트 실행 시작
# 목표:
# '인공지능 시장 규모'에 대해 조사하고,
# 다음 정보를 포함한 종합 보고서를 작성해줘:
# 1. 현재 시장 규모
# 2. 성장 추세
# 3. 주요 플레이어
# 4. 향후 전망
#
# ================================================================================
#
# [반복 1/10]
# 생각: 인공지능 시장 규모에 대한 종합 보고서를 작성하기 위해서는 먼저 현재 시장 규모, 성장 추세, 주요 플레이어, 향후 전망에 대한 정보를 수집해야 한다. 웹 검색을 통해 최신 데이터를 찾아보겠다.
# 행동: web_search
# 결과: # 인공지능 시장 규모 2024 현황 및 전망
#
# ## 검색 결과
#
# ### 1. 글로벌 AI 시장 규모 급성장
# **출처: 시장조사기관 종합 보고서**
#
# 2024년 글로벌 인공지능 시장 규모는 약 **5,000억 달러(약 650조원)** 규모로 추정된다. 2023년 대비 약 35-40%의 높은 성장률을 기록하고 있으며, 생성형 AI의 상용화가 주요 성장 동력으...
#
# [반복 2/10]
# 생각: 웹 검색을 통해 인공지능 시장 규모에 대한 기본 정보를 얻었다. 2024년 글로벌 AI 시장 규모가 약 5,000억 달러(650조원)이고 35-40% 성장률을 보이고 있다는 정보를 확보했다. 이제 이 텍스트를 분석하여 더 구체적인 인사이트를 도출하고, 추가로 필요한 정보(주요 플레이어, 향후 전망 등)를 파악해야 한다.
# 행동: text_analyzer
# 결과: # 텍스트 분석 결과
#
# ## 1. 감정 분석
#
# **분석 결과: 긍정적 (Positive)**
#
# - **긍정 지표**: "높은 성장률", "상용화", "성장 동력" 등의 표현이 시장의 활발한 발전을 나타낸다
# - **객관성**: 수치 데이터 중심의 서술로 과도한 감정 표현 없이 사실을 전달한다
# - **전망**: 미래 지향적이고 낙관적인 톤을 유지한다
#
# **예시...
#
# [반복 3/10]
# 생각: 웹 검색과 텍스트 분석을 통해 현재 시장 규모(5,000억 달러)와 성장 추세(35-40% 성장률)에 대한 기본 정보를 얻었다. 하지만 종합 보고서를 작성하기 위해서는 주요 플레이어와 향후 전망에 대한 더 구체적인 정보가 필요하다. 추가 웹 검색을 통해 주요 기업들과 미래 예측 데이터를 수집하겠다.
# 행동: web_search
# 결과: # 인공지능 시장 주요 기업 및 2024년 향후 전망
#
# ## 검색 결과
#
# ### 1. **OpenAI - ChatGPT와 GPT-4의 지속적 진화**
# **요약:** OpenAI는 2024년 GPT-4 Turbo와 차세대 모델 개발을 통해 시장 선도 위치를 강화하고 있다. 기업용 API 서비스 확대와 Microsoft와의 전략적 파트너십을 통해 연간 매출 2...
#
# [반복 4/10]
# 생각: 이제 충분한 정보를 수집했다. 현재 시장 규모(5,000억 달러), 성장 추세(35-40% 성장률), 주요 플레이어(OpenAI, Microsoft 등)에 대한 데이터를 확보했다. 그러나 더 정확한 향후 전망 수치를 계산하기 위해 calculator를 사용하여 미래 시장 규모를 예측하고, 이를 바탕으로 종합 보고서를 작성하겠다.
# 행동: calculator
# 결과: # 계산 과정
#
# 5000 × 1.35를 계산하겠다.
#
# ## 단계별 계산
#
# ```
# 5000 × 1.35
# = 5000 × (1 + 0.35)
# = 5000 × 1 + 5000 × 0.35
# = 5000 + 1750
# = 6750
# ```
#
# ## 최종 결과
#
# **5000 × 1.35 = 6,750**
#
# 이 계산은 5000에 35%를 더한 값과 같다....
#
# [반복 5/10]
# 생각: 수집한 모든 정보를 바탕으로 종합 보고서를 작성할 준비가 되었다. 현재 시장 규모(5,000억 달러), 성장 추세(35-40% 성장), 주요 플레이어(OpenAI, Microsoft 등), 그리고 계산된 향후 전망 수치(6,750억 달러)를 모두 확보했다. 이제 이 정보들을 체계적으로 정리하여 요청받은 4가지 항목을 모두 포함한 종합 보고서를 작성하겠다.
# 행동: FINISH
#
# 최종 답변: # 인공지능 시장 규모 종합 보고서
#
# ================================================================================
# 최종 결과
# ================================================================================
# # 인공지능 시장 규모 종합 보고서

# %% [markdown]
# ## 6-6. Plan-Execute 에이전트
#
# 먼저 전체 계획을 수립한 후 단계별로 실행하는 에이전트다.

# %%
class PlanExecuteAgent:
    """
    계획 수립 후 실행하는 Plan-Execute 패턴 에이전트
    """
    
    def __init__(self, api_key: Optional[str] = None):
        """
        Plan-Execute 에이전트를 초기화한다
        """
        self.client = anthropic.Anthropic()
        self.skills: Dict[str, Dict] = {}
        self.plan: List[Dict] = []  # 실행 계획
    
    def load_skill(self, skill_path: str) -> None:
        """Skill을 로드한다"""
        with open(skill_path, 'r', encoding='utf-8') as f:
            skill_data = yaml.safe_load(f)
        
        skill_name = skill_data['name']
        self.skills[skill_name] = skill_data
        print(f"도구 등록: {skill_name}")
    
    def create_plan(self, goal: str) -> List[Dict]:
        """
        목표 달성을 위한 계획을 수립한다
        
        Args:
            goal: 달성할 목표
            
        Returns:
            단계별 계획 리스트
        """
        tools_description = "\n".join([
            f"- {name}: {skill['description']}"
            for name, skill in self.skills.items()
        ])
        
        prompt = f"""
다음 목표를 달성하기 위한 단계별 계획을 수립해줘:

목표: {goal}

사용 가능한 도구:
{tools_description}

다음 형식으로 3-5단계의 계획을 작성해줘:

1. [단계 설명]
   도구: [사용할 도구 이름]
   입력: [도구에 전달할 내용]

2. [단계 설명]
   도구: [사용할 도구 이름]
   입력: [도구에 전달할 내용]

...
"""
        
        response = self.client.messages.create(
            model=MODEL,
            max_tokens=2000,
            temperature=0.7,
            messages=[{"role": "user", "content": prompt}]
        )
        
        plan_text = response.content[0].text
        
        # 계획 파싱 (간단한 정규식 사용)
        steps = []
        step_blocks = re.findall(
            r'\d+\.\s*(.+?)\s*도구:\s*(.+?)\s*입력:\s*(.+?)(?=\n\d+\.|$)',
            plan_text,
            re.DOTALL
        )
        
        for description, tool, input_text in step_blocks:
            steps.append({
                'description': description.strip(),
                'tool': tool.strip(),
                'input': input_text.strip()
            })
        
        return steps
    
    def execute_step(self, step: Dict) -> str:
        """
        단일 단계를 실행한다
        
        Args:
            step: 실행할 단계
            
        Returns:
            실행 결과
        """
        tool_name = step['tool']
        
        if tool_name not in self.skills:
            return f"오류: '{tool_name}' 도구를 찾을 수 없다"
        
        skill = self.skills[tool_name]
        config = skill.get('config', {})
        
        response = self.client.messages.create(
            model=config.get('model', MODEL),
            max_tokens=config.get('max_tokens', 2000),
            temperature=config.get('temperature', 0.7),
            system=skill['content'],
            messages=[{"role": "user", "content": step['input']}]
        )
        
        return response.content[0].text
    
    def run(self, goal: str) -> Dict[str, Any]:
        """
        에이전트를 실행한다
        
        Args:
            goal: 달성할 목표
            
        Returns:
            실행 결과 딕셔너리
        """
        print("\n" + "=" * 80)
        print("Plan-Execute 에이전트 실행")
        print("=" * 80)
        print(f"\n목표: {goal}")
        
        # 1단계: 계획 수립
        print("\n[1단계: 계획 수립]")
        self.plan = self.create_plan(goal)
        
        print(f"\n수립된 계획 ({len(self.plan)}단계):")
        for i, step in enumerate(self.plan, 1):
            print(f"\n{i}. {step['description']}")
            print(f"   도구: {step['tool']}")
        
        # 2단계: 실행
        print("\n" + "=" * 80)
        print("[2단계: 계획 실행]")
        print("=" * 80)
        
        results = []
        for i, step in enumerate(self.plan, 1):
            print(f"\n[{i}/{len(self.plan)}] {step['description']}")
            result = self.execute_step(step)
            results.append({
                'step': step['description'],
                'result': result
            })
            print(f"완료 (결과 길이: {len(result)} 문자)")
        
        print("\n" + "=" * 80)
        print("계획 실행 완료")
        print("=" * 80)
        
        return {
            'goal': goal,
            'plan': self.plan,
            'results': results
        }

print("PlanExecuteAgent 클래스 정의 완료")
# Out:
# PlanExecuteAgent 클래스 정의 완료

# %% [markdown]
# ## 6-7. 예제 2: 코딩 어시스턴트 에이전트

# %%
# Plan-Execute 에이전트 생성
coding_agent = PlanExecuteAgent()

# 도구 로드
coding_agent.load_skill('skills/agent_workflow/web_search.yaml')
coding_agent.load_skill('skills/agent_workflow/code_generator.yaml')
coding_agent.load_skill('skills/agent_workflow/text_analyzer.yaml')

print("\n코딩 어시스턴트 에이전트 준비 완료")
# Out:
# 도구 등록: web_search
# 도구 등록: code_generator
# 도구 등록: text_analyzer
#
# 코딩 어시스턴트 에이전트 준비 완료

# %%
# 에이전트 실행
coding_goal = """
Python으로 CSV 파일을 읽어서 데이터 시각화하는 완전한 프로그램을 만들어줘.
pandas와 matplotlib를 사용하고, 주석을 포함해야 한다.
"""

coding_result = coding_agent.run(coding_goal)

# 최종 결과 출력
print("\n" + "=" * 80)
print("최종 생성된 코드")
print("=" * 80)
final_code = coding_result['results'][-1]['result']
print(final_code)
# Out:
# ================================================================================
# Plan-Execute 에이전트 실행
# ================================================================================
#
# 목표:
# Python으로 CSV 파일을 읽어서 데이터 시각화하는 완전한 프로그램을 만들어줘.
# pandas와 matplotlib를 사용하고, 주석을 포함해야 한다.
#
#
# [1단계: 계획 수립]
#
# 수립된 계획 (1단계):
#
# 1. 필요한 라이브러리 및 기본 구조 조사
#    **
#    도구: ** web_search
#    **
#
# ================================================================================
# [2단계: 계획 실행]
# ================================================================================
#
# [1/1] 필요한 라이브러리 및 기본 구조 조사
#    **
# 완료 (결과 길이: 37 문자)
#
# ================================================================================
# 계획 실행 완료
# ================================================================================
#
# ================================================================================
# 최종 생성된 코드
# ================================================================================
# 오류: '** web_search
#    **' 도구를 찾을 수 없다

# %% [markdown]
# ## 6-8. 워크플로우 결과 저장 및 분석

# %%
def save_agent_results(
    agent_type: str,
    results: Union[str, Dict],
    memory: Optional[AgentMemory] = None,
    output_dir: str = "agent_outputs"
) -> None:
    """
    에이전트 실행 결과를 저장한다
    
    Args:
        agent_type: 에이전트 타입 (react, plan_execute 등)
        results: 실행 결과
        memory: 에이전트 메모리 (선택)
        output_dir: 출력 디렉토리
    """
    output_path = Path(output_dir)
    output_path.mkdir(exist_ok=True)
    
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    run_dir = output_path / f"{agent_type}_{timestamp}"
    run_dir.mkdir(exist_ok=True)
    
    # 결과 저장
    if isinstance(results, dict):
        # Plan-Execute 결과
        with open(run_dir / "results.json", 'w', encoding='utf-8') as f:
            json.dump(results, f, ensure_ascii=False, indent=2)
        
        # 마크다운 보고서
        with open(run_dir / "report.md", 'w', encoding='utf-8') as f:
            f.write(f"# {agent_type.upper()} 에이전트 실행 보고서\n\n")
            f.write(f"실행 시간: {timestamp}\n\n")
            f.write(f"## 목표\n{results['goal']}\n\n")
            f.write(f"## 계획\n")
            for i, step in enumerate(results['plan'], 1):
                f.write(f"{i}. {step['description']}\n")
            f.write(f"\n## 실행 결과\n")
            for i, result in enumerate(results['results'], 1):
                f.write(f"\n### 단계 {i}: {result['step']}\n")
                f.write(f"{result['result']}\n")
    else:
        # ReAct 결과
        with open(run_dir / "result.txt", 'w', encoding='utf-8') as f:
            f.write(results)
    
    # 메모리 저장
    if memory:
        memory_data = {
            'goal': memory.goal,
            'observations': memory.observations,
            'thoughts': memory.thoughts,
            'actions': memory.actions,
            'results': memory.results,
            'learnings': memory.learnings
        }
        with open(run_dir / "memory.json", 'w', encoding='utf-8') as f:
            json.dump(memory_data, f, ensure_ascii=False, indent=2)
    
    print(f"\n결과 저장 완료: {run_dir}")

# 결과 저장
if research_agent.memory:
    save_agent_results(
        agent_type="react",
        results=result,
        memory=research_agent.memory
    )

save_agent_results(
    agent_type="plan_execute",
    results=coding_result
)
# Out:
# 결과 저장 완료: agent_outputs/react_20251108_174159
#
# 결과 저장 완료: agent_outputs/plan_execute_20251108_174159

# %% [markdown]
# ## 6-9. 생성된 파일 목록

# %%
print("\n" + "=" * 80)
print("생성된 모든 파일")
print("=" * 80)

# Skills
print("\n[에이전트 Skills]")
for file_path in sorted(skills_dir.glob("*.yaml")):
    size = file_path.stat().st_size
    print(f"  {file_path.name} ({size:,} bytes)")

# 에이전트 출력
agent_output_dir = Path("agent_outputs")
if agent_output_dir.exists():
    print("\n[에이전트 실행 결과]")
    for run_dir in sorted(agent_output_dir.glob("*")):
        print(f"  {run_dir.name}/")
        for file_path in sorted(run_dir.glob("*")):
            size = file_path.stat().st_size
            print(f"    {file_path.name} ({size:,} bytes)")
# Out:
# ================================================================================
# 생성된 모든 파일
# ================================================================================
#
# [에이전트 Skills]
#   calculator.yaml (567 bytes)
#   code_generator.yaml (815 bytes)
#   text_analyzer.yaml (710 bytes)
#   web_search.yaml (860 bytes)
#
# [에이전트 실행 결과]
#   plan_execute_20251108_174159/
#     .ipynb_checkpoints (96 bytes)
#     report.md (481 bytes)
#     results.json (2,763 bytes)
#   react_20251108_174159/
#     memory.json (13,795 bytes)
#     result.txt (45 bytes)
