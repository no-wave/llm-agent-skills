# %% [markdown]
# # 챕터 4: Landing Page Guide Skill 예제 구현
#
# ## 4-1. Landing Page Guide Skill 개요
#
# 실제 프로젝트에서 사용할 수 있는 랜딩 페이지 생성 Skill을 구현한다.
#
# 이 Skill은 다음 기능을 제공한다:
# - 현대적인 랜딩 페이지 HTML/CSS/JavaScript 생성
# - 반응형 디자인
# - SEO 최적화
# - 접근성 고려
# - 다양한 섹션 구성

# %%
from dotenv import load_dotenv
import os

load_dotenv()
MODEL = "claude-sonnet-4-5"

# %%
import anthropic
import os
from pathlib import Path
import yaml
from typing import Dict, List, Optional
from dataclasses import dataclass
import json

# Anthropic 클라이언트 초기화
client = anthropic.Anthropic()

print("환경 설정 완료")
# Out:
# 환경 설정 완료

# %% [markdown]
# ## 4-2. Landing Page Guide Skill 정의
#
# 전문적인 랜딩 페이지를 생성하는 Skill을 작성한다.

# %%
# Landing Page Guide Skill 내용
landing_page_skill_content = """# 랜딩 페이지 전문가 Skill

## 역할
현대적이고 전환율이 높은 랜딩 페이지를 설계하고 코드로 구현하는 전문가다.

## 핵심 원칙

### 1. 디자인 원칙
- **명확한 가치 제안**: 첫 화면에서 핵심 가치를 즉시 전달한다
- **시각적 계층**: 중요한 정보를 시각적으로 강조한다
- **여백 활용**: 충분한 여백으로 가독성을 높인다
- **일관된 브랜딩**: 색상, 폰트, 톤앤매너를 일관되게 유지한다

### 2. 구조 원칙
랜딩 페이지는 다음 섹션으로 구성한다:

1. **Hero Section (히어로 섹션)**
   - 강력한 헤드라인
   - 명확한 서브헤드라인
   - 눈에 띄는 CTA 버튼
   - 관련 이미지나 동영상

2. **Features Section (기능 섹션)**
   - 3-6개의 핵심 기능
   - 각 기능에 아이콘과 설명
   - 혜택 중심으로 작성

3. **Social Proof (사회적 증거)**
   - 고객 후기
   - 신뢰할 수 있는 기업 로고
   - 통계 및 성과 지표

4. **How It Works (작동 방식)**
   - 3-4단계로 설명
   - 간단하고 명확한 프로세스
   - 시각적 요소 활용

5. **Pricing (가격)**
   - 명확한 가격 정보
   - 옵션별 비교
   - 추천 플랜 강조

6. **FAQ (자주 묻는 질문)**
   - 일반적인 우려사항 해소
   - 5-8개의 질문과 답변

7. **Final CTA (최종 행동 유도)**
   - 강력한 재촉구
   - 긴급성이나 희소성 활용

### 3. 기술 구현 원칙

#### HTML 구조
- 시맨틱 HTML5 태그 사용 (header, nav, main, section, article, footer)
- 접근성을 위한 ARIA 속성 포함
- SEO를 위한 메타 태그 완비

#### CSS 스타일링
- 모바일 우선 반응형 디자인
- CSS Grid와 Flexbox 활용
- CSS 변수로 테마 관리
- 부드러운 애니메이션과 전환 효과
- 다크모드 지원 고려

#### JavaScript 기능
- 스크롤 애니메이션
- 폼 검증
- 스무스 스크롤
- 모바일 메뉴 토글
- 성능 최적화 (Lazy Loading 등)

### 4. 성능 최적화
- 이미지 최적화 (WebP, lazy loading)
- CSS/JS 최소화
- Critical CSS 인라인 처리
- 폰트 최적화

### 5. SEO 최적화
- 적절한 title과 meta description
- Open Graph 태그
- Schema.org 구조화된 데이터
- 명확한 heading 계층 (h1, h2, h3)

## 코드 출력 형식

### 단일 파일 HTML
모든 CSS와 JavaScript를 포함한 완전한 HTML 파일을 생성한다:

```html
<!DOCTYPE html>
<html lang="ko">
<head>
    <!-- 메타 태그 -->
    <style>
        /* CSS 코드 */
    </style>
</head>
<body>
    <!-- HTML 구조 -->
    <script>
        // JavaScript 코드
    </script>
</body>
</html>
```

### 코드 품질
- 주석으로 섹션을 명확히 구분한다
- 일관된 들여쓰기와 네이밍 컨벤션을 사용한다
- 재사용 가능한 컴포넌트 구조로 작성한다

## 응답 스타일
- 문장은 ~다 체를 사용한다
- 기술적으로 정확하고 실용적인 조언을 제공한다
- 실제 동작하는 완전한 코드를 생성한다
- 커스터마이징 가이드를 함께 제공한다
"""

# skills 디렉토리 생성
skills_dir = Path("skills/landing_page")
skills_dir.mkdir(exist_ok=True)

# Markdown 파일로 저장
landing_page_md_path = skills_dir / "landing_page_guide.md"
with open(landing_page_md_path, "w", encoding="utf-8") as f:
    f.write(landing_page_skill_content)

print(f"Landing Page Skill 생성: {landing_page_md_path}")
# Out:
# Landing Page Skill 생성: skills/landing_page/landing_page_guide.md

# %%
# YAML 메타데이터 생성
landing_page_yaml = {
    'name': 'landing_page_guide',
    'version': '1.0.0',
    'description': '고전환율 랜딩 페이지 생성 전문가',
    'author': 'Skills Tutorial',
    'tags': ['web', 'landing-page', 'html', 'css', 'javascript', 'marketing'],
    'config': {
        'model': MODEL,
        'max_tokens': 8000,
        'temperature': 0.7
    },
    'content': landing_page_skill_content
}

landing_page_yaml_path = skills_dir / "landing_page_guide.yaml"
with open(landing_page_yaml_path, "w", encoding="utf-8") as f:
    yaml.dump(landing_page_yaml, f, allow_unicode=True, default_flow_style=False)

print(f"Landing Page YAML 메타데이터 생성: {landing_page_yaml_path}")
# Out:
# Landing Page YAML 메타데이터 생성: skills/landing_page/landing_page_guide.yaml

# %% [markdown]
# ## 4-3. SkillAgent 클래스 준비

# %%
class LandingPageAgent:
    """
    랜딩 페이지 생성에 특화된 에이전트
    """
    
    def __init__(self, api_key: Optional[str] = None):
        """
        에이전트를 초기화한다
        
        Args:
            api_key: Anthropic API 키
        """
        self.client = anthropic.Anthropic(
            api_key=api_key or os.environ.get("ANTHROPIC_API_KEY")
        )
        self.skill_content = None
        self.skill_config = None
    
    def load_skill(self, skill_path: str) -> None:
        """
        Skill 파일을 로드한다
        
        Args:
            skill_path: Skill YAML 파일 경로
        """
        with open(skill_path, 'r', encoding='utf-8') as f:
            skill_data = yaml.safe_load(f)
        
        self.skill_content = skill_data['content']
        self.skill_config = skill_data.get('config', {})
        
        print(f"Skill 로드 완료: {skill_data['name']} v{skill_data['version']}")
    
    def generate_landing_page(
        self,
        product_name: str,
        product_description: str,
        target_audience: str,
        key_features: List[str],
        color_scheme: Optional[str] = None
    ) -> str:
        """
        랜딩 페이지를 생성한다
        
        Args:
            product_name: 제품/서비스 이름
            product_description: 제품/서비스 설명
            target_audience: 타겟 고객
            key_features: 핵심 기능 목록
            color_scheme: 색상 스킴 (선택)
            
        Returns:
            생성된 HTML 코드
        """
        # 프롬프트 구성
        features_text = "\n".join([f"- {feature}" for feature in key_features])
        
        user_prompt = f"""
다음 정보를 바탕으로 완전한 랜딩 페이지를 만들어줘:

**제품명**: {product_name}

**제품 설명**: {product_description}

**타겟 고객**: {target_audience}

**핵심 기능**:
{features_text}
"""
        
        if color_scheme:
            user_prompt += f"\n**색상 스킴**: {color_scheme}\n"
        
        user_prompt += """

요구사항:
1. 모든 CSS와 JavaScript를 포함한 단일 HTML 파일을 생성한다
2. 반응형 디자인을 적용한다
3. Hero, Features, How It Works, FAQ, CTA 섹션을 포함한다
4. 실제 동작하는 완전한 코드를 작성한다
5. 주석으로 각 섹션을 명확히 표시한다
6. HTML 코드만 출력하고 다른 설명은 포함하지 않는다
"""
        
        # API 호출
        response = self.client.messages.create(
            model=self.skill_config.get('model', MODEL),
            max_tokens=self.skill_config.get('max_tokens', 8000),
            temperature=self.skill_config.get('temperature', 0.7),
            system=self.skill_content,
            messages=[
                {
                    "role": "user",
                    "content": user_prompt
                }
            ]
        )
        html_text = response.content[0].text
        return html_text
    
    def save_landing_page(self, html_content: str, output_path: str) -> None:
        """
        생성된 랜딩 페이지를 파일로 저장한다
        
        Args:
            html_content: HTML 내용
            output_path: 저장할 파일 경로
        """
        print(f"\n원본 HTML 길이: {len(html_content)} 문자")
        
        original_content = html_content
        
        if '```html' in html_content:
            start = html_content.find('```html') + 7
            end = html_content.rfind('```')
            if end > start:
                html_content = html_content[start:end].strip()
                print(f"HTML 블록 추출 완료")
        elif '```' in html_content:
            start = html_content.find('```') + 3
            end = html_content.rfind('```')
            if end > start:
                html_content = html_content[start:end].strip()
                print(f"코드 블록 추출 완료")
        
        if not html_content.strip().startswith('<!DOCTYPE') and not html_content.strip().startswith('<html'):
            print(f"HTML 태그가 없어서 원본 사용")
            html_content = original_content
        
        print(f"저장할 HTML 길이: {len(html_content)} 문자")
        
        with open(output_path, 'w', encoding='utf-8') as f:
            f.write(html_content)
        
        file_size = Path(output_path).stat().st_size
        print(f"랜딩 페이지 저장 완료: {output_path}")
        print(f"파일 크기: {file_size:,} bytes")

print("LandingPageAgent 클래스 정의 완료")
# Out:
# LandingPageAgent 클래스 정의 완료

# %% [markdown]
# ## 4-4. 실전 예제 1: SaaS 제품 랜딩 페이지

# %%
# 에이전트 생성 및 Skill 로드
agent = LandingPageAgent()
agent.load_skill('skills/landing_page/landing_page_guide.yaml')

print("\n" + "=" * 80)
print("예제 1: AI 기반 작문 도구 랜딩 페이지 생성")
print("=" * 80)
# Out:
# Skill 로드 완료: landing_page_guide v1.0.0
#
# ================================================================================
# 예제 1: AI 기반 작문 도구 랜딩 페이지 생성
# ================================================================================

# %%
# 랜딩 페이지 생성
html_content_1 = agent.generate_landing_page(
    product_name="WriteMaster AI",
    product_description="AI가 도와주는 스마트 작문 도구. 블로그, 이메일, 보고서 작성을 10배 빠르게 완성하세요.",
    target_audience="콘텐츠 크리에이터, 마케터, 비즈니스 전문가",
    key_features=[
        "AI 기반 문장 제안 및 자동 완성",
        "50개 이상의 글쓰기 템플릿",
        "실시간 문법 및 맞춤법 검사",
        "다양한 톤과 스타일 지원",
        "팀 협업 기능"
    ],
    color_scheme="모던한 파란색과 흰색 조합"
)

print("\n랜딩 페이지 생성 완료!")
print(f"생성된 HTML 길이: {len(html_content_1)} 문자")
# Out:
# 랜딩 페이지 생성 완료!
# 생성된 HTML 길이: 23560 문자

# %%
# 생성된 랜딩 페이지 저장
output_dir = Path("output_landing_page")
output_dir.mkdir(exist_ok=True)

output_path_1 = output_dir / "writemaster_landing.html"
agent.save_landing_page(html_content_1, str(output_path_1))

print(f"\n파일 경로: {output_path_1.absolute()}")
print("브라우저에서 열어서 확인할 수 있다")
# Out:
# 원본 HTML 길이: 23560 문자
# HTML 태그가 없어서 원본 사용
# 저장할 HTML 길이: 23560 문자
# 랜딩 페이지 저장 완료: output_landing_page/writemaster_landing.html
# 파일 크기: 25,521 bytes
#
# 파일 경로: /Users/namuai/03-books/agent-skills/output_landing_page/writemaster_landing.html
# 브라우저에서 열어서 확인할 수 있다

# %% [markdown]
# ## 4-5. 실전 예제 2: 모바일 앱 랜딩 페이지

# %%
print("\n" + "=" * 80)
print("예제 2: 피트니스 트래킹 앱 랜딩 페이지 생성")
print("=" * 80)

html_content_2 = agent.generate_landing_page(
    product_name="FitTrack Pro",
    product_description="AI 개인 트레이너가 당신의 건강을 책임진다. 맞춤형 운동 계획과 영양 관리를 한 곳에서.",
    target_audience="운동을 시작하고 싶은 초보자, 체계적인 관리가 필요한 헬스 애호가",
    key_features=[
        "AI 기반 맞춤형 운동 계획",
        "실시간 자세 교정 및 피드백",
        "칼로리 및 영양소 추적",
        "진행 상황 시각화 대시보드",
        "커뮤니티 챌린지 참여",
        "웨어러블 기기 연동"
    ],
    color_scheme="활동적인 오렌지색과 검정색 조합"
)

output_path_2 = output_dir / "fittrack_landing.html"
agent.save_landing_page(html_content_2, str(output_path_2))

print(f"\n파일 경로: {output_path_2.absolute()}")
# Out:
# ================================================================================
# 예제 2: 피트니스 트래킹 앱 랜딩 페이지 생성
# ================================================================================
#
# 원본 HTML 길이: 26145 문자
# HTML 태그가 없어서 원본 사용
# 저장할 HTML 길이: 26145 문자
# 랜딩 페이지 저장 완료: output_landing_page/fittrack_landing.html
# 파일 크기: 27,632 bytes
#
# 파일 경로: /Users/namuai/03-books/agent-skills/output_landing_page/fittrack_landing.html

# %% [markdown]
# ## 4-6. 실전 예제 3: 이커머스 제품 랜딩 페이지

# %%
print("\n" + "=" * 80)
print("예제 3: 프리미엄 커피 구독 서비스 랜딩 페이지 생성")
print("=" * 80)

html_content_3 = agent.generate_landing_page(
    product_name="Bean Journey",
    product_description="세계 각지의 스페셜티 커피를 매달 문 앞으로. 바리스타가 엄선한 원두로 집에서 즐기는 카페 경험.",
    target_audience="커피를 사랑하는 사람들, 새로운 맛을 탐험하고 싶은 호기심 많은 소비자",
    key_features=[
        "매달 다른 나라의 스페셜티 원두 배송",
        "바리스타의 추출 가이드 포함",
        "원두 농장 스토리와 테이스팅 노트",
        "로스팅 후 7일 이내 신선 배송",
        "언제든지 변경/취소 가능한 유연한 구독",
        "첫 구매 20% 할인"
    ],
    color_scheme="따뜻한 갈색과 크림색 조합"
)

output_path_3 = output_dir / "beanjourney_landing.html"
agent.save_landing_page(html_content_3, str(output_path_3))

print(f"\n파일 경로: {output_path_3.absolute()}")
# Out:
# ================================================================================
# 예제 3: 프리미엄 커피 구독 서비스 랜딩 페이지 생성
# ================================================================================
#
# 원본 HTML 길이: 25694 문자
# HTML 태그가 없어서 원본 사용
# 저장할 HTML 길이: 25694 문자
# 랜딩 페이지 저장 완료: output_landing_page/beanjourney_landing.html
# 파일 크기: 27,194 bytes
#
# 파일 경로: /Users/namuai/03-books/agent-skills/output_landing_page/beanjourney_landing.html

# %% [markdown]
# ## 4-7. 생성된 파일 확인 및 분석

# %%
import re

def analyze_html(file_path: str) -> Dict:
    """
    생성된 HTML 파일을 분석한다
    
    Args:
        file_path: 분석할 HTML 파일 경로
        
    Returns:
        분석 결과 딕셔너리
    """
    with open(file_path, 'r', encoding='utf-8') as f:
        content = f.read()
    
    # 기본 통계
    stats = {
        'file_size': len(content),
        'line_count': content.count('\n'),
    }
    
    # HTML 요소 분석
    stats['sections'] = content.count('<section')
    stats['has_hero'] = 'hero' in content.lower()
    stats['has_features'] = 'feature' in content.lower()
    stats['has_cta'] = 'cta' in content.lower() or 'call-to-action' in content.lower()
    stats['has_faq'] = 'faq' in content.lower()
    
    # CSS 분석
    stats['has_css'] = '<style' in content
    stats['has_responsive'] = '@media' in content
    
    # JavaScript 분석
    stats['has_javascript'] = '<script' in content
    
    # SEO 요소
    stats['has_meta_description'] = 'meta name="description"' in content
    stats['has_og_tags'] = 'og:' in content
    
    return stats

print("\n" + "=" * 80)
print("생성된 랜딩 페이지 분석")
print("=" * 80)

for output_file in output_dir.glob("*.html"):
    print(f"\n파일: {output_file.name}")
    stats = analyze_html(str(output_file))
    
    print(f"  크기: {stats['file_size']:,} 문자")
    print(f"  라인 수: {stats['line_count']:,}")
    print(f"  섹션 수: {stats['sections']}")
    print(f"  주요 요소:")
    print(f"    - Hero 섹션: {'있음' if stats['has_hero'] else '없음'}")
    print(f"    - Features: {'있음' if stats['has_features'] else '없음'}")
    print(f"    - CTA: {'있음' if stats['has_cta'] else '없음'}")
    print(f"    - FAQ: {'있음' if stats['has_faq'] else '없음'}")
    print(f"  기술 요소:")
    print(f"    - CSS: {'있음' if stats['has_css'] else '없음'}")
    print(f"    - 반응형: {'있음' if stats['has_responsive'] else '없음'}")
    print(f"    - JavaScript: {'있음' if stats['has_javascript'] else '없음'}")
    print(f"  SEO:")
    print(f"    - Meta Description: {'있음' if stats['has_meta_description'] else '없음'}")
    print(f"    - Open Graph: {'있음' if stats['has_og_tags'] else '없음'}")
# Out:
# ================================================================================
# 생성된 랜딩 페이지 분석
# ================================================================================
#
# 파일: writemaster_landing.html
#   크기: 23,560 문자
#   라인 수: 774
#   섹션 수: 4
#   주요 요소:
#     - Hero 섹션: 있음
#     - Features: 있음
#     - CTA: 있음
#     - FAQ: 있음
#   기술 요소:
#     - CSS: 있음
#     - 반응형: 있음
#     - JavaScript: 없음
#   SEO:
#     - Meta Description: 있음
#     - Open Graph: 있음
#
# 파일: beanjourney_landing.html
#   크기: 25,694 문자
#   라인 수: 898
#   섹션 수: 4
#   주요 요소:
#     - Hero 섹션: 있음
#     - Features: 있음
#     - CTA: 있음
#     - FAQ: 있음
#   기술 요소:
#     - CSS: 있음
#     - 반응형: 있음
#     - JavaScript: 없음
#   SEO:
#     - Meta Description: 있음
#     - Open Graph: 있음
#
# 파일: fittrack_landing.html
#   크기: 26,145 문자
#   라인 수: 906
#   섹션 수: 4
#   주요 요소:
#     - Hero 섹션: 있음
#     - Features: 있음
#     - CTA: 있음
#     - FAQ: 있음
#   기술 요소:
#     - CSS: 있음
#     - 반응형: 있음
#     - JavaScript: 없음
#   SEO:
#     - Meta Description: 있음
#     - Open Graph: 있음

# %% [markdown]
# ## 4-8. 커스터마이징 가이드 생성

# %%
# 커스터마이징 가이드 생성
customization_guide = """
# 랜딩 페이지 커스터마이징 가이드

## 색상 변경하기
HTML 파일의 `<style>` 섹션 상단에 있는 CSS 변수를 수정한다:

```css
:root {
    --primary-color: #your-color;    /* 주 색상 */
    --secondary-color: #your-color;  /* 보조 색상 */
    --text-color: #your-color;       /* 텍스트 색상 */
    --bg-color: #your-color;         /* 배경 색상 */
}
```

## 텍스트 수정하기
1. Hero 섹션의 헤드라인과 서브헤드라인을 수정한다
2. Features 섹션에서 각 기능의 제목과 설명을 변경한다
3. CTA 버튼 텍스트를 목적에 맞게 수정한다

## 이미지 추가하기
```html
<img src="your-image.jpg" alt="설명">
```

플레이스홀더 이미지를 실제 이미지로 교체한다.
추천 이미지 소스:
- Unsplash (unsplash.com)
- Pexels (pexels.com)

## 폰트 변경하기
`<head>` 섹션에 Google Fonts를 추가한다:

```html
<link href="https://fonts.googleapis.com/css2?family=Your+Font&display=swap" rel="stylesheet">
```

CSS에서 폰트를 적용한다:
```css
body {
    font-family: 'Your Font', sans-serif;
}
```

## 섹션 추가/제거하기
1. 필요한 섹션을 찾는다 (주석으로 표시되어 있음)
2. 전체 `<section>` 태그를 복사하거나 삭제한다
3. ID와 클래스명을 중복되지 않게 수정한다

## 반응형 조정하기
미디어 쿼리를 수정하여 브레이크포인트를 조정한다:

```css
@media (max-width: 768px) {
    /* 모바일 스타일 */
}
```

## 애니메이션 수정하기
CSS 애니메이션 속도와 타이밍을 조정한다:

```css
transition: all 0.3s ease;  /* 속도를 0.3초에서 원하는 값으로 */
```

## SEO 최적화
1. `<title>` 태그 수정
2. Meta description 작성
3. Open Graph 태그 정보 업데이트
4. Alt 텍스트를 모든 이미지에 추가

## 폼 연동하기
실제 이메일 수집을 위해 폼 액션을 설정한다:

```html
<form action="your-form-handler" method="POST">
    <!-- 폼 필드 -->
</form>
```

추천 서비스:
- Formspree
- Netlify Forms
- Google Forms

## 분석 도구 추가하기
`</head>` 태그 직전에 Google Analytics 코드를 추가한다:

```html
<!-- Google Analytics -->
<script async src="https://www.googletagmanager.com/gtag/js?id=GA_MEASUREMENT_ID"></script>
```
"""

guide_path = output_dir / "CUSTOMIZATION_GUIDE.md"
with open(guide_path, 'w', encoding='utf-8') as f:
    f.write(customization_guide)

print(f"커스터마이징 가이드 생성: {guide_path}")
# Out:
# 커스터마이징 가이드 생성: output_landing_page/CUSTOMIZATION_GUIDE.md

# %% [markdown]
# ## 4-9. 생성된 파일 목록

# %%
print("\n" + "=" * 80)
print("생성된 모든 파일")
print("=" * 80)

print("\n[Skills]")
for file_path in sorted(skills_dir.glob("landing_page*")):
    size = file_path.stat().st_size
    print(f"  {file_path.name} ({size:,} bytes)")

print("\n[Output]")
for file_path in sorted(output_dir.glob("*")):
    size = file_path.stat().st_size
    print(f"  {file_path.name} ({size:,} bytes)")
# Out:
# ================================================================================
# 생성된 모든 파일
# ================================================================================
#
# [Skills]
#   landing_page_guide.md (3,098 bytes)
#   landing_page_guide.yaml (3,597 bytes)
#
# [Output]
#   .ipynb_checkpoints (160 bytes)
#   CUSTOMIZATION_GUIDE.md (2,318 bytes)
#   beanjourney_landing.html (27,194 bytes)
#   fittrack_landing.html (27,632 bytes)
#   writemaster_landing.html (25,521 bytes)
